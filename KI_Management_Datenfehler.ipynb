# %% [markdown]
# <a href="https://colab.research.google.com/github/1989-juliana-h/hello-world/blob/master/KI_Management_Datenfehler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the sales data from the "Colab Notebooks" folder in Google Drive
try:
    sales_df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/view_de_sample_dirty.csv")
    print("Data loaded successfully!")
except FileNotFoundError:
    print("Error: 'view_de_sample.csv' not found in '/content/drive/My Drive/Colab Notebooks/'. Please check the file name and path.")
    sales_df = None # Ensure sales_df is defined even if file loading fails
# Out:
# Data loaded successfully!

# %%
sales_df.head()
# Out:
#          date avg_price     sales black_friday corona_cases email_sendouts  \
# 0  2019-01-01      76.0   81940.0          0.0          0.0            NaN
# 1  2019-01-02      78.0  107555.0          0.0          0.0        23802.0
# 2  2019-01-03      79.0  119142.0          0.0          0.0        15205.0
# 3  2019-01-04      79.0  117725.0          0.0          0.0        24296.0
# 4  2019-01-05      78.0  151778.0          0.0          0.0        25573.0
#
#   influencer_reach google_trend tv_brand_grp tv_sale_grp  pla_clicks  \
# 0       14434508.0        15.99          0.0         0.0     59338.0
# 1              0.0        14.82          0.0         0.0     66488.0
# 2              0.0        14.04          0.0         0.0    102260.0
# 3              0.0        12.87          0.0         0.0    108136.0
# 4              0.0        16.77          0.0         0.0    132834.0
#
#   seanb_clicks seanb_impressions youtube_non_sale_impressions  \
# ...

# %% [markdown]
# Pakete, für Visualisierungen in Python: Matplotlib, Seaborn & Plotly
